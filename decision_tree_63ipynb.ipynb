# %%
import matplotlib.pyplot as plt
import pandas as pd
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
import matplotlib.pyplot as plt
df=pd.read_csv("/Users/student/Downloads/decision tree .csv")
print(df)
d={'UK':0,'USA':1,'N':2,'INDIA':3}
df['Nationality']=df['Nationality'].map(d)
d={'YES':1,'NO':0}
df['Go']=df['Go'].map(d)
features=['Age','Experience','Rank','Nationality']
X=df[features]
y=df['Go']
dtree=DecisionTreeClassifier()
dtree=dtree.fit(X,y)
tree.plot_tree(dtree,feature_names=features)
plt.show()
# Out:
#    Age  Experience  Rank Nationality   Go
# 0   30           9     8         USA   NO
# 1   25           3     9       INDIA  YES
# 2   29           6     3          UK   NO
# 3   40          15     7          N   YES
# 4   35          10     5          UK  YES
# 5   45          20     9         USA   NO
# 6   52          32     7           N   NO
# 7   50          30     6           N  YES
# 8   47          17     5       INDIA   NO
# 9   26           5     2       INDIA  YES
